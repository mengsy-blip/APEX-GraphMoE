# %% [markdown]
# # DeepSeek LoRA Fine-Tuning
#
# This notebook runs the cleaned fine-tuning script from `LLN/src/finetune_deepseek_lora.py`.

# %%
# !torchrun --nproc_per_node=2 ../src/finetune_deepseek_lora.py \
  --model_name deepseek-ai/deepseek-llm-7b-chat \
  --training_data ../data/training_data/all_scenes_training.json \
  --output_dir ../models/lora_model
